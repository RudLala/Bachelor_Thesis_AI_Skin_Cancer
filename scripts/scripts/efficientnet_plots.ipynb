# %%
import matplotlib.pyplot as plt

epochs = list(range(1, 16))

train_accuracy = [
    0.2813, 0.3403, 0.3839, 0.4236, 0.4501,
    0.4700, 0.4805, 0.5022, 0.5264, 0.5329,
    0.5499, 0.5561, 0.5682, 0.5731, 0.5725
]

val_accuracy = [
    0.4385, 0.5014, 0.5301, 0.5560, 0.5806,
    0.6018, 0.6100, 0.6120, 0.6195, 0.6175,
    0.6230, 0.6216, 0.6236, 0.6264, 0.6366
]

train_loss = [
    1.8148, 1.6135, 1.4931, 1.3982, 1.3349,
    1.2757, 1.2459, 1.2081, 1.1673, 1.1411,
    1.1028, 1.0833, 1.0418, 1.0392, 1.0258
]

val_loss = [
    1.3869, 1.2603, 1.1941, 1.1329, 1.0761,
    1.0523, 1.0203, 1.0014, 0.9706, 0.9531,
    0.9333, 0.9291, 0.9090, 0.8977, 0.8891
]

plt.figure(figsize=(8,5))
plt.plot(epochs, train_accuracy, label="Training Accuracy")
plt.plot(epochs, val_accuracy, label="Validation Accuracy")
plt.title("EfficientNetB0 Accuracy Curve")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.tight_layout()
plt.savefig("/home/jovyan/results/efficientnet_accuracy_curve.png")
plt.show()

plt.figure(figsize=(8,5))
plt.plot(epochs, train_loss, label="Training Loss")
plt.plot(epochs, val_loss, label="Validation Loss")
plt.title("EfficientNetB0 Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.tight_layout()
plt.savefig("/home/jovyan/results/efficientnet_loss_curve.png")
plt.show()
